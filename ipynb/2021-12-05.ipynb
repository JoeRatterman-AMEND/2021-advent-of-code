# %%
# Load input data
file_path = "C:\\Users\\JoeRatterman\\Documents\\GitHub\\2021-advent-of-code\\input-files\\2021-12-05_input.txt"
data_list = open(file_path, 'r').read().split('\n')

# # Convert list to integers
# data_list = data_list[0].split(",")
# data_list = [int(x) for x in data_list]

print(data_list[0:10])
data_list = list(map(lambda s: s.split(" -> "), data_list))
data_list
# Out:
# ['0,9 -> 5,9', '8,0 -> 0,8', '9,4 -> 3,4', '2,2 -> 2,1', '7,0 -> 7,4', '6,4 -> 2,0', '0,9 -> 2,9', '3,4 -> 1,4', '0,0 -> 8,8', '5,5 -> 8,2']
# [['0,9', '5,9'],
#  ['8,0', '0,8'],
#  ['9,4', '3,4'],
#  ['2,2', '2,1'],
#  ['7,0', '7,4'],
#  ['6,4', '2,0'],
#  ['0,9', '2,9'],
#  ['3,4', '1,4'],
#  ['0,0', '8,8'],
#  ['5,5', '8,2']]

# %%
def convert(list):
    return tuple(list)

# %%
for i in range(len(data_list)):
    print(tuple(data_list[i][0][0] + data_list[i][0][2] + data_list[i][1][0] + data_list[i][1][2]))
# Out:
# ('0', '9', '5', '9')
# ('8', '0', '0', '8')
# ('9', '4', '3', '4')
# ('2', '2', '2', '1')
# ('7', '0', '7', '4')
# ('6', '4', '2', '0')
# ('0', '9', '2', '9')
# ('3', '4', '1', '4')
# ('0', '0', '8', '8')
# ('5', '5', '8', '2')

# %%
# create multi-dim array by providing shape
matrix = numpy.empty(shape=(2,5),dtype='object')
print(matrix)

# %%
period_len = 256
input_data = np.asarray(data_list.copy())

for i in range(period_len):
   print(i)
   # Subtract 1 day to reproduce
   input_data = input_data - 1
 
   # Count number of fish that will reproduce
   rep_cnt = np.count_nonzero(input_data == 0)

   # Extend list 
   append_= np.full((rep_cnt), 8)
   print(append_)
   input_data = np.append(input_data, append_)

   # Reset fish count
   input_data = np.where(input_data < 0, 6, input_data)


print(input_data)
print(len(input_data))
# Out:
# 0
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8]
# 1
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8]
# 2
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8]
# 3
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8]
# 4
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8]
# 5
# []
# 6
# []
# 7
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8]
# 8
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
# ...

# %%
np.full((rep_cnt), 8)
# Out:
# array([8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8,
#        8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8,
#        8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8,
#        8, 8, 8])

# %%
def life_generator(n):
    while True:
        if n == 0:
            yield n
            n = 6
        else:
            yield n
            n -= 1


class Lanternfish:
    def __init__(self, n):
        self.n = n

    def next(self):
        if self.n == 0:
            self.n = 6
        else:
            self.n -= 1

    def __str__(self):
        return f'{self.n}'

    def __repr__(self):
        return f'{self.n}'


class FishSchool:
    def __init__(self, counts):
        self.max_life = 8
        self.n = [0] * (self.max_life + 1)
        for k, v in counts.items():
            self.n[k] = v

    def next(self):
        num_zero = self.n[0]
        for d in range(1, 9):
            self.n[d-1] = self.n[d]

        self.n[6] += num_zero
        self.n[8] = num_zero

    def __repr__(self):
        return repr(self.n)

    def __str__(self):
        return str(self.n)

# Part 1
state = list(map(Lanternfish, data))
num_days = 80
print(f'Current state: {state}')
for _ in range(num_days):
    # print(f'Start {_ + 1:2d} days: {state}')
    num_zero = sum(map(lambda x: x.n == 0, state))
    for fish in state:
        fish.next()

    for j in range(num_zero):
        state.append(Lanternfish(8))
    # print(f'  End {_+1:2d} days: {state}')

print(f'Total number of fish after {num_days} days: {len(state)}')


# Part 2
state = FishSchool(counts)
num_days = 256
for _ in range(num_days):
    state.next()

print(f'Total fish: {sum(state.n)}')
